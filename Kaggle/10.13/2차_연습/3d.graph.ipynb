# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('./data/South_Korean_Age_Distribution.csv')
df
# Out:
#                region  year  male_total    m_0_4    m_5_9  m_10_14  m_15_19  \
# 0         Countrywide  2010    25024388  1185171  1276671  1702359  1887106
# 1               Seoul  2010     5020033   218486   223661   298301   352784
# 2               Busan  2010     1749116    66150    73804   107033   132248
# 3               Daegu  2010     1241448    53294    63257    90699   105187
# 4             Incheon  2010     1372352    65915    69892    94150   109315
# ..                ...   ...         ...      ...      ...      ...      ...
# 209      North Jeolla  2021      885369    23633    37825    43029    44962
# 210      South Jeolla  2021      918957    25839    37245    41756    42596
# 211  North Gyeongsang  2021     1318237    37045    54852    57502    58867
# 212  South Gyeongsang  2021     1661208    49994    78962    84431    81935
# 213              Jeju  2021      337285    11847    17917    18801    17970
#
# ...

# %%
## 지역, 년도,
## 총 인구수: 0 ~ 19, 20 ~ 39, 40 ~ 59, 60 ~ 79, 80 ~ 100+
# df['t_0_19'] = df['m_0_4'] + df['m_5_9'] + df['m_10_14'] + df['m_15_19']
# df['t_20_39'] = df
# df['t_40_59'] =
# df['t_60_79'] =
# df['t_80_100+']

# 년도
# 총 인구수
# 연령별 인구수
# df = df.groupby([ 'region', 'year' ], as_index = False)['male_total'].sum()
df = df.groupby([ 'region', 'year' ], as_index = False)['male_total'].agg('sum')

df
# Out:
#     region  year  male_total
# 0    Busan  2010     1749116
# 1    Busan  2011     1741085
# 2    Busan  2012     1732956
# 3    Busan  2013     1726562
# 4    Busan  2014     1720938
# ..     ...   ...         ...
# 209  Ulsan  2017      595854
# 210  Ulsan  2018      590317
# 211  Ulsan  2019      586217
# 212  Ulsan  2020      580482
# 213  Ulsan  2021      573865
#
# [214 rows x 3 columns]

# %%
fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(projection = '3d')

# xs = np.arange(0, len(df) + 1, 1)
# ys = np.arange(min(df.year), max(df.year))

### 좌표 설정
X = np.array(list(df['region'].index))
print(X.shape)
Y = np.array(list(df['year']))
print(Y.shape)
Z = np.array(list(df['male_total'])) ## 백만 단위

ax.scatter3D(X, Y, Z)

plt.show()
# Out:
# (214,)
# (214,)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xs=['str1', 'str2', 'str3', 'str4']
ys=['str5', 'str6', 'str7', 'str8']
zs=[1,2,3,4]

ax.scatter(range(len(xs)), range(len(xs)), zs)
ax.set(xticks=range(len(xs)), xticklabels=xs,
	yticks=range(len(xs)), yticklabels=xs)
# Out:
# [[<matplotlib.axis.XTick at 0x7fee0019ec40>,
# ...
#  [Text(0, 0, 'str1'),
#   Text(1, 0, 'str2'),
#   Text(2, 0, 'str3'),
#   Text(3, 0, 'str4')],
# ...
#  [Text(0, 0, 'str1'),
#   Text(1, 0, 'str2'),
#   Text(2, 0, 'str3'),
#   Text(3, 0, 'str4')]]
